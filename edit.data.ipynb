# %%
import pandas as pd

# %%
df = pd.read_csv('book.txt')
df
# Out:
#           نام         نام خانوادگي جنسيت  کد پرسنلي  \
# 0         صفر         خدادادي  گله   مرد   58908864
# 1     اسماعيل                 عيدي   مرد   58909191
# 2    ذوالفقار           غيبي  نژاد   مرد   12472519
# 3       سامان        قاسمي قاسموند   مرد   94027747
# 4       مرتضي        قاسمي قاسموند   مرد   94049517
# ..        ...                  ...   ...        ...
# 159      رسول    زماني احمد محمودي   مرد   31010063
# 160      كريم                كريمي   مرد   58909087
# 161     شهناز  كمال  الدين  دهكردي    زن   59001581
# 162      محمد         يوسفي بابادي   مرد   13077343
# 163    خداداد     کريمي مالک آبادي   مرد   31000691
#
#                             پست سازماني              محل خدمت مدرک تحصيلي  \
# 0    مدير مجتمع آموزشي و پرورشي روستايي  معلم راهنماي روستايي      ليسانس
# 1    مدير مجتمع آموزشي و پرورشي روستايي  معلم راهنماي روستايي      ليسانس
# 2    مدير مجتمع آموزشي و پرورشي روستايي  معلم راهنماي روستايي      ليسانس
# ...

# %%
df['نام'] = df['نام'] + ' ' + df['نام خانوادگي']


print(df.columns)
df.drop(columns=['نام خانوادگي'], inplace= True)

df
# Out:
# Index(['نام', 'نام خانوادگي', 'جنسيت', 'کد پرسنلي', ' پست سازماني', 'محل خدمت',
#        'مدرک تحصيلي', 'رشته تحصيلي', 'سال بازنشستگی', 'ماه بازنشستگی',
#        'سال دولتی', 'ماه دولتی', 'شماره موبایل'],
#       dtype='object')
#                            نام جنسيت  کد پرسنلي  \
# 0             صفر خدادادي  گله   مرد   58908864
# 1                 اسماعيل عيدي   مرد   58909191
# 2          ذوالفقار غيبي  نژاد   مرد   12472519
# 3          سامان قاسمي قاسموند   مرد   94027747
# 4          مرتضي قاسمي قاسموند   مرد   94049517
# ..                         ...   ...        ...
# 159     رسول زماني احمد محمودي   مرد   31010063
# 160                 كريم كريمي   مرد   58909087
# 161  شهناز كمال  الدين  دهكردي    زن   59001581
# 162          محمد يوسفي بابادي   مرد   13077343
# 163    خداداد کريمي مالک آبادي   مرد   31000691
#
#                             پست سازماني              محل خدمت مدرک تحصيلي  \
# 0    مدير مجتمع آموزشي و پرورشي روستايي  معلم راهنماي روستايي      ليسانس
# ...

# %%
ebtedaei_male = df[(df['جنسيت'] == 'مرد') & (df[' پست سازماني'] == 'مدير مدرسه دوره ابتدايي')]

ebtedaei_male.to_excel('مدیران_ابتدایی.xlsx', index=False, engine='openpyxl')

# %%
ebtedaei_f = df[(df['جنسيت'] == 'زن') & (df[' پست سازماني'] == 'مدير مدرسه دوره ابتدايي')]

ebtedaei_f.to_excel('مدیران_ابتدایی_زن.xlsx', index=False, engine='openpyxl')

# %%
ebtedaei_male = df[(df['جنسيت'] == 'مرد') & (df[' پست سازماني'] == 'مدير مدرسه دوره ابتدايي')]

ebtedaei_male.to_excel('مدیران_ابتدایی.xlsx', index=False, engine='openpyxl')

# %%
ebtedaei_male_ma = df[(df['جنسيت'] == 'مرد') & (df[' پست سازماني'] == 'مدیرآموزگار')]

ebtedaei_male_ma.to_excel('مدیر آموزگاران مرد.xlsx', index=False, engine='openpyxl')
